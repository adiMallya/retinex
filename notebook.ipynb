# %%
import os
import numpy as np
import cv2

import matplotlib.pyplot as plt
from IPython.display import display 
# %matplotlib inline

# %%
PATH = "input"

img_list = os.listdir(PATH)
img_list
# Out:
# ['horse_rider.jpg',
#  'lighthouse.jpg',
#  'airfield.jpg',
#  'coronary_ang.jpg',
#  'aerial_view.jpeg',
#  'iris.jpg',
#  'girl.jpg',
#  'foggy_buildings.jpeg',
#  'fractured_bone.jpeg',
#  'bio.jpeg']

# %%
from src.utils import read_show
image = read_show(PATH,img_list[1],show=True)

# %%
SIGMA_LIST = [15, 80, 250]
ALPHA = 125.0
BETA = 46.0
G = 192
b = -30

# %%
from src.retinex import MSRCR

msrcr_img = MSRCR(image,SIGMA_LIST,ALPHA,BETA,G,b)

# %%
from src.utils import plot_hist

plot_hist(image, msrcr_img)
